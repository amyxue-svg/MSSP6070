# %% [markdown]
# <a href="https://colab.research.google.com/github/amyxue-svg/MSSP6070/blob/main/Modules/Week4/Participation_Activity_Week_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %run '/content/drive/MyDrive/MSSP 6070/Google_connection.py'
# Out:
# Changed directory to: /content/MSSP6070

# %%
import numpy as np
import pandas as pd
PREVIOUS_MAX_ROWS = pd.options.display.max_rows
pd.options.display.max_rows = 20
np.random.seed(12345)
import matplotlib.pyplot as plt
plt.rc('figure', figsize=(10, 6))
np.set_printoptions(precision=4, suppress=True)

# %%
df = pd.read_csv('/content/drive/MyDrive/MSSP 6070/Modules/Week 4/parsed.csv')

# %% [markdown]
# 2a

# %%
mb = df["magType"]=="mb"
Japan = df["place"].str.contains("Japan")
japanmb = df[Japan & mb]
japanmb["mag"].quantile(0.95)
# Out:
# np.float64(5.119999999999999)

# %% [markdown]
# 2b

# %%
Indonesia = df["place"].str.contains("Indonesia")
Indonesia = df[Indonesia]
Indonesia["tsunami"].value_counts()
tsunami_percentage = Indonesia["tsunami"].value_counts()[1]/len(Indonesia)
print(tsunami_percentage)
# Out:
# 0.23129251700680273

# %% [markdown]
# 2c

# %%
Nevada = df["place"].str.contains("Nevada")
Nevada.describe()
# Out:
# count      9332
# unique        2
# top       False
# freq       8655
# Name: place, dtype: object

# %% [markdown]
# 2d

# %%
Ring_of_fire = ("Bolivia|Chile|Ecuador|Peru|Costa Rica|Guatemala|Mexico|Japan|Philippines|Indonesia|New Zealand|Antarctic|Canada|Fiji|Alaska|Washington|California|Russia|Taiwan|Tonga|Kermadec Islands")
df["Ring_of_fire"] = df["parsed_place"].str.contains(Ring_of_fire) & ~df["parsed_place"].str.contains("New Mexico")
df[["place","Ring_of_fire"]].head()
# Out:
#                    place  Ring_of_fire
# 0  9km NE of Aguanga, CA          True
# 1  9km NE of Aguanga, CA          True
# 2  8km NE of Aguanga, CA          True
# 3  9km NE of Aguanga, CA          True
# 4  10km NW of Avenal, CA          True

# %% [markdown]
# 2e

# %%
df["Ring_of_fire"].value_counts()
# Out:
# Ring_of_fire
# True     7188
# False    2144
# Name: count, dtype: int64

# %% [markdown]
# 2f

# %%
tsunami_Ring_of_fire = df[df[Ring_of_fire]]["tsunami"].value_counts()
print(tsunami_Ring_of_fire)
# Out:
# tsunami
# 0    4383
# 1      43
# Name: count, dtype: int64
